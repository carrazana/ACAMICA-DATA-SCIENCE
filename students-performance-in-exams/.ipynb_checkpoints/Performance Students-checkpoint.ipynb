# %%
import utils
import importlib
importlib.reload(utils)
from utils import *

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
path_dataset = 'StudentsPerformance.csv'
df = pd.read_csv(path_dataset)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count    1000.000       1000.000       1000.000
# mean       66.089         69.169         68.054
# std        15.163         14.600         15.196
# min         0.000         17.000         10.000
# 25%        57.000         59.000         57.750
# 50%        66.000         70.000         69.000
# 75%        77.000         79.000         79.000
# max       100.000        100.000        100.000

# %%
pd.get_dummies(pd.Series(list('abcaa')), drop_first=True)

# %%
#from sklearn.preprocessing import LabelEncoder

#le = LabelEncoder()
#le.fit(df['gender'])
#df['gender']=le.transform(df['gender'])

# %%
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0         0        group B           bachelor's degree      standard
# 1         0        group C                some college      standard
# 2         0        group B             master's degree      standard
# 3         1        group A          associate's degree  free/reduced
# 4         1        group C                some college      standard
# 5         0        group B          associate's degree      standard
# 6         0        group B                some college      standard
# 7         1        group B                some college  free/reduced
# 8         1        group D                 high school  free/reduced
# 9         0        group B                 high school  free/reduced
# 10        1        group C          associate's degree      standard
# 11        1        group D          associate's degree      standard
# 12        0        group B                 high school      standard
# 13        1        group A                some college      standard
# 14        0        group A             master's degree      standard
# 15        0        group C            some high school      standard
# 16        1        group C                 high school      standard
# 17        0        group B            some high school  free/reduced
# 18        1        group C             master's degree  free/reduced
# 19        0        group C          associate's degree  free/reduced
# 20        1        group D                 high school      standard
# 21        0        group B                some college  free/reduced
# 22        1        group D                some college      standard
# 23        0        group C            some high school      standard
# 24        1        group D           bachelor's degree  free/reduced
# 25        1        group A             master's degree  free/reduced
# 26        1        group B                some college      standard
# 27        0        group C           bachelor's degree      standard
# 28        1        group C                 high school      standard
# 29        0        group D             master's degree      standard
# ..      ...            ...                         ...           ...
# 970       0        group D           bachelor's degree      standard
# 971       1        group C            some high school      standard
# 972       0        group A                 high school  free/reduced
# 973       0        group D                some college  free/reduced
# 974       0        group A                some college      standard
# 975       0        group C                some college      standard
# 976       1        group B                some college  free/reduced
# 977       1        group C          associate's degree      standard
# 978       1        group D                 high school      standard
# 979       0        group C          associate's degree      standard
# 980       0        group B                 high school  free/reduced
# 981       1        group D            some high school      standard
# 982       1        group B            some high school      standard
# 983       0        group A                some college      standard
# 984       0        group C            some high school      standard
# 985       1        group A                 high school      standard
# 986       0        group C          associate's degree      standard
# 987       1        group E            some high school      standard
# 988       0        group A            some high school  free/reduced
# 989       0        group D                some college  free/reduced
# 990       1        group E                 high school  free/reduced
# 991       0        group B            some high school      standard
# 992       0        group D          associate's degree  free/reduced
# 993       0        group D           bachelor's degree  free/reduced
# 994       1        group A                 high school      standard
# 995       0        group E             master's degree      standard
# 996       1        group C                 high school  free/reduced
# 997       0        group C                 high school  free/reduced
# 998       0        group D                some college      standard
# 999       0        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# 5                      none          71             83             78
# 6                 completed          88             95             92
# 7                      none          40             43             39
# 8                 completed          64             64             67
# 9                      none          38             60             50
# 10                     none          58             54             52
# 11                     none          40             52             43
# 12                     none          65             81             73
# 13                completed          78             72             70
# 14                     none          50             53             58
# 15                     none          69             75             78
# 16                     none          88             89             86
# 17                     none          18             32             28
# 18                completed          46             42             46
# 19                     none          54             58             61
# 20                     none          66             69             63
# 21                completed          65             75             70
# 22                     none          44             54             53
# 23                     none          69             73             73
# 24                completed          74             71             80
# 25                     none          73             74             72
# 26                     none          69             54             55
# 27                     none          67             69             75
# 28                     none          70             70             65
# 29                     none          62             70             75
# ..                      ...         ...            ...            ...
# 970                    none          89            100            100
# 971               completed          78             72             69
# 972               completed          53             50             60
# 973                    none          49             65             61
# 974                    none          54             63             67
# 975               completed          64             82             77
# 976               completed          60             62             60
# 977                    none          62             65             58
# 978               completed          55             41             48
# 979                    none          91             95             94
# 980                    none           8             24             23
# 981                    none          81             78             78
# 982               completed          79             85             86
# 983               completed          78             87             91
# 984                    none          74             75             82
# 985                    none          57             51             54
# 986                    none          40             59             51
# 987               completed          81             75             76
# 988                    none          44             45             45
# 989               completed          67             86             83
# 990               completed          86             81             75
# 991               completed          65             82             78
# 992                    none          55             76             76
# 993                    none          62             72             74
# 994                    none          63             63             62
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]
